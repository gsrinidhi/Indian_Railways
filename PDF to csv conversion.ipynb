# %%
from PyPDF2 import PdfReader

reader = PdfReader("../T_1.pdf")
number_of_pages = len(reader.pages)
page = reader.pages[0]
text = page.extract_text()
print(text)
# Out:
# TRAIN NAMEDelhiAlipur-duar Jn. SikkimMahan-andaExpressKalkaHowrahNetajiEx-pressBarm-erHow-rahEx-pressNewDelhiRajgirShram-jeeviExpressNewDelhiGayaMa-habodhiEx-pressAnandVihar (T) Ka-makhyaNorthEast Ex-pressAnandVihar (T) Bhagal-purVikram ShilaExpressAnandVihar (T) DanapurJanSad-haranExpressAnandVihar (T)GayaGaribrath Ex-pressAnandVihar (T)HaldiaEx-pressPrayagRaj Ram-baghHowrahVib huti ExpressBikanerPrayag-rajExpressBikanerPrayag-rajExpressPatnaKol-kataGaribRathEx-pressVeerangna Laxmi Bai  KolkataPrathamSwatantrataSangramExpressKanpurPrayagrajsangamExpressPatnaShali-marDuron-toEx-pressGhazi-purcityKolkataExpress (ViaPatna)AnandVihar (T Prayag-rajHum-safarExpressAnandVihar (T) Mad-hupurHum-safarExpressAnandVihar (T) MadhupurBaba Vaidy-anath Dham DeogharExpressMoka-maHow-rahEx-pressJasi-dih-SM-VTBengal-uru Ex-pressTrain Number 15484 12312 12324 12392 12398 12506 12368 13258 22410 12444 12334 12404 20404 12360 22198 14102 22214 13122 22438 22460 22466 13030 22306 Class of accommodation 2A,3A SL,II,P1A,2A,3A SL,II,P2A,3A SL,II1A,2A,3A,SL,II,P2A,3A SL,II,P2A,3A SL,II,P1A,2A,3A SL,II,PII 3A 3A,SL, II2A,3A SL,II1A,2A,3A, 3E, SL,II1A,2A,3A, 3E, SL,II3A 2A, 3A, SL,II II 1A,2A, 3A SL2A, 3A, SL, II3A, SL 3A, SL 2A,3A, SL,II SL,II
# 1A, 2A, 3A,SL,II,P
# From Table No. 27A 59A via 25 80 80 35A 22 Days of departure atoriginating station Daily Daily W,Sa Daily Daily Daily Daily Daily Sa Tu Daily Tu,W,F,-SuM,Th,SaSu,W,FF DailyTu,Th, SaMTu,Th, SuM W Daily FKm.
# Delhiad07.3506.0007.1507.3007.55
# New Delhiad13.10 12.50
# 13 Anand Vihar (T) d 07.40 13.15 13.35 20.20 20.20 22.35 12.45 12.45
# 25 Ghaziabad d 08.16 07.00 ... 13.51 ... ... ... 20.47 20.4795 Khurja d 09.05 07.58126 Aligarh d 09.50 08.35 ... 14.30 09.13 ... ...145
# Mathura d 19.5019.5519.5019.55 199 Agra Cantt. d 21.05 21.05204 Tundla ad11.0311.0509.5009.55... ... 10.3010.32... ...221 Firozabad d 11.28 10.13 ... ... ... ...241 Shikohabad d ... 10.38 ... ... ... ...296 Etawah d 12.18 11.23 ... ... 11.43 ... ... 23.38 23.38435 Kanpur ad14.4514.5513.4513.5513.3513.4517.5518.0013.2513.3518.2518.3001.1001.1501.1001.1501.3001.3501.3001.35GOY00.5501.00
folder_name = "tables"
if not os.path.isdir(folder_name):
    os.mkdir(folder_name)
# iterate over extracted tables and export as excel individually
for i, table in enumerate(tables, start=1):
    table.to_excel(os.path.join(folder_name, f"table_{i}.xlsx"), index=False)

# %%
tables[0]
# Out:
#               Unnamed: 0     Delhi   Kalka  Barm-      New    New.1     Anand  \
# 0                    NaN   Alipur-  Howrah     er    Delhi    Delhi     Vihar
# 1                    NaN  duar Jn.  Netaji   How-   Rajgir     Gaya   (T) Ka-
# 2             TRAIN NAME    Sikkim     Ex-    rah   Shram-      Ma-    makhya
# 3                    NaN    Mahan-   press    Ex-    jeevi  habodhi     North
# 4                    NaN      anda     NaN  press  Express      Ex-  East Ex-
# ..                   ...       ...     ...    ...      ...      ...       ...
# 102        1453 Howrah a       NaN   08.05  06.00      NaN      NaN       NaN
# 103   Days of arrival at       NaN     NaN    NaN      NaN      NaN       NaN
# 104                  NaN     Daily   Daily  Th,Su    Daily    Daily     Daily
# 105  destination station       NaN     NaN    NaN      NaN      NaN       NaN
# 106         To Table No.        18     NaN    NaN       67      NaN        18
#
#        Anand.1    Anand.2   Anand.3  ...   Patna    Veerangna     Kanpur  \
# 0    Vihar (T)  Vihar (T)     Vihar  ...    Kol-    Laxmi Bai  Prayagraj
# 1      Bhagal-    Danapur       (T)  ...    kata      Kolkata     sangam
# 2          pur        Jan      Gaya  ...   Garib      Pratham    Express
# 3       Vikram       Sad-     Garib  ...    Rath  Swatantrata        NaN
# 4        Shila      haran  rath Ex-  ...     Ex-      Sangram        NaN
# ..         ...        ...       ...  ...     ...          ...        ...
# 102        NaN        NaN       NaN  ...     NaN          NaN        NaN
# 103        NaN        NaN       NaN  ...  M,Th,-          NaN        NaN
# 104      Daily      Daily        Su  ...     NaN           Sa      Daily
# 105        NaN        NaN       NaN  ...      Sa          NaN        NaN
# 106        NaN        NaN       NaN  ...     NaN          NaN        NaN
#
#     Patna.1   Ghazi-   Anand.5    Anand.6      Anand.7  Moka-    Jasi-
# 0    Shali-      pur  Vihar (T  Vihar (T)    Vihar (T)     ma  dih-SM-
# 1       mar     city   Prayag-       Mad-     Madhupur   How-       VT
# 2    Duron-  Kolkata       raj      hupur  Baba Vaidy-    rah  Bengal-
# 3        to    Expre      Hum-       Hum-   anath Dham    Ex-  uru Ex-
# 4       Ex-  ss (Via     safar      safar      Deoghar  press    press
# ..      ...      ...       ...        ...          ...    ...      ...
# 102     NaN      NaN       NaN        NaN          NaN  03.00      NaN
# 103     NaN      NaN       NaN        NaN          NaN    NaN      NaN
# 104  W,F,Su       Tu     W,F,M         Tu           Th  Daily       Sa
# 105     NaN      NaN       NaN        NaN          NaN    NaN      NaN
# 106     NaN      NaN       NaN        NaN          NaN    NaN       40
#
# [107 rows x 24 columns]

# %%
tables[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 tables[0][0]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 0

# %%
tables[0].Bikaner[6]
# Out:
# '12404'

# %%
tables[0]['Train Number']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3800, in Index.get_loc(self, key, method, tolerance)
#    3799 try:
# -> 3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Train Number'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 tables[0]['Train Number']
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3800     return self._engine.get_loc(casted_key)
#    3801 except KeyError as err:
# -> 3802     raise KeyError(key) from err
#    3803 except TypeError:
#    3804     # If we have a listlike key, _check_indexing_error will raise
#    3805     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3806     #  the TypeError.
#    3807     self._check_indexing_error(key)
#
# KeyError: 'Train Number'
