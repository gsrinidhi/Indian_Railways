# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
d1 = pd.read_csv('../Train_details_22122017.csv')

# %%
G = nx.Graph()
for i in range(0,len(d1['Train No'])):
    if i < len(d1['Train No']) - 1:
        if d1['SEQ'][i+1] != 1:
            G.add_edge(d1['Station Code'][i],d1['Station Code'][i+1])

# %%
print(len(G.nodes()))
# Out:
# 8148

# %%
print(len(G.edges()))
# Out:
# 14465

# %%
nx.draw(G,node_size=10)

# %%
no_of_stations = len(d1['Station Code'].unique())
print(no_of_stations)
# Out:
# 8148

# %%
no_of_Trains = len(d1['Train No'].unique())
print(no_of_Trains)
# Out:
# 11112

# %%
degree1 = dict(G.degree)
for d in degree1.keys():
    if degree1[d] == max(degree1.values()):
        print(d)
        print("Maximum degree = " + str(max(degree1.values())))
# Out:
# MGS
# Maximum degree = 44

# %%
degree1 = dict(G.degree)
major_G = nx
count = 0
for d in degree1.keys():
    if degree1[d] == 1:
        print(d)
        count = 
        print("Maximum degree = " + str(max(degree1.values())))
# Out:
# KDS
# Maximum degree = 44
# SZE
# Maximum degree = 44
# JLWC
# Maximum degree = 44
# MKM
# Maximum degree = 44
# COA
# Maximum degree = 44
# VLNK
# Maximum degree = 44
# NS
# Maximum degree = 44
# KRDL
# Maximum degree = 44
# SMNH
# Maximum degree = 44
# BBN
# Maximum degree = 44
# KGM
# Maximum degree = 44
# IPR
# Maximum degree = 44
# CAPE
# Maximum degree = 44
# PTPL
# Maximum degree = 44
# FN
# Maximum degree = 44
# AADR
# Maximum degree = 44
# RKSH
# Maximum degree = 44
# SHTT
# Maximum degree = 44
# TCN
# Maximum degree = 44
# GUV
# Maximum degree = 44
# TLGP
# Maximum degree = 44
# NIL
# Maximum degree = 44
# RAL
# Maximum degree = 44
# GAD
# Maximum degree = 44
# JNRD
# Maximum degree = 44
# SKTN
# Maximum degree = 44
# KLYM
# Maximum degree = 44
# HNB
# Maximum degree = 44
# BGB
# Maximum degree = 44
# KGK
# Maximum degree = 44
# CG
# Maximum degree = 44
# NMKA
# Maximum degree = 44
# SPS
# Maximum degree = 44
# AMBG
# Maximum degree = 44
# AMZ
# Maximum degree = 44
# DHI
# Maximum degree = 44
# BRMT
# Maximum degree = 44
# BIR
# Maximum degree = 44
# NIR
# Maximum degree = 44
# KNH
# Maximum degree = 44
# GWO
# Maximum degree = 44
# SOE
# Maximum degree = 44
# DHOA
# Maximum degree = 44
# SRMT
# Maximum degree = 44
# TPO
# Maximum degree = 44
# SZP
# Maximum degree = 44
# BRK
# Maximum degree = 44
# NPR
# Maximum degree = 44
# JDNX
# Maximum degree = 44
# DJ
# Maximum degree = 44
# ADIJ
# Maximum degree = 44
# DASF
# Maximum degree = 44
# JLRF
# Maximum degree = 44
# DVA
# Maximum degree = 44
# KODR
# Maximum degree = 44
# SWD
# Maximum degree = 44
# SNDT
# Maximum degree = 44
# KWAR
# Maximum degree = 44
# RJL
# Maximum degree = 44
# GRD
# Maximum degree = 44
# TRG
# Maximum degree = 44
# SHTS
# Maximum degree = 44
# ETAH
# Maximum degree = 44
# JJJ
# Maximum degree = 44
# BARA
# Maximum degree = 44
# BHJ
# Maximum degree = 44
# MGZ
# Maximum degree = 44
# MJZ
# Maximum degree = 44
# BXT
# Maximum degree = 44
# BHBR
# Maximum degree = 44
# BIRL
# Maximum degree = 44
# MBO
# Maximum degree = 44
# MSSN
# Maximum degree = 44
# VNGP
# Maximum degree = 44
# BHRB
# Maximum degree = 44
# UDPU
# Maximum degree = 44
# DLCR
# Maximum degree = 44
# SQB
# Maximum degree = 44
# BHNG
# Maximum degree = 44
# MNDP
# Maximum degree = 44
# MTDM
# Maximum degree = 44
# UAM
# Maximum degree = 44
# CMGR
# Maximum degree = 44
# EDN
# Maximum degree = 44
# BJM
# Maximum degree = 44
# MCLA
# Maximum degree = 44
# BDHN
# Maximum degree = 44
# GUA
# Maximum degree = 44
# BRMP
# Maximum degree = 44
# BXF
# Maximum degree = 44
# NYGT
# Maximum degree = 44
# KDRI
# Maximum degree = 44
# DTR
# Maximum degree = 44
# RIM
# Maximum degree = 44
# RTK
# Maximum degree = 44
# TRDI
# Maximum degree = 44
# ITRN
# Maximum degree = 44
# NABN
# Maximum degree = 44
# KTNA
# Maximum degree = 44
# CTD
# Maximum degree = 44
# MDSA
# Maximum degree = 44
# VTL
# Maximum degree = 44
# RAJ
# Maximum degree = 44
# RJU
# Maximum degree = 44
# PTN
# Maximum degree = 44
# PUHT
# Maximum degree = 44
# HRF
# Maximum degree = 44
# DGFJ
# Maximum degree = 44
# DDCL
# Maximum degree = 44
# BDB
# Maximum degree = 44
# DIT
# Maximum degree = 44
# PTG
# Maximum degree = 44
# DDG
# Maximum degree = 44
# BRML
# Maximum degree = 44
# DBNK
# Maximum degree = 44
# KEMK
# Maximum degree = 44
# QDN
# Maximum degree = 44
# MEC
# Maximum degree = 44
# SRDR
# Maximum degree = 44
# TNPR
# Maximum degree = 44
# DNGI
# Maximum degree = 44
# KPLH
# Maximum degree = 44
# PDMI
# Maximum degree = 44
# JKAR
# Maximum degree = 44
# BMPR
# Maximum degree = 44
# GMMG
# Maximum degree = 44
# SALR
# Maximum degree = 44
# KGE
# Maximum degree = 44
# GUDM
# Maximum degree = 44
# CBY
# Maximum degree = 44
# AJM
# Maximum degree = 44
# UMNF
# Maximum degree = 44
# MNKD
# Maximum degree = 44
# CMBR
# Maximum degree = 44
# NEU
# Maximum degree = 44

# %%
Major_G = list(nx.connected_components(G))
print(Major_G)
# Out:
# [{'BGZ', 'BKPR', 'NKW', 'ETR', 'BVR', 'KGN', 'SSGR', 'BTR', 'CDB', 'UBR', 'DGG', 'GTJT', 'NIIJ', 'FRDH', 'SSG', 'DGPP', 'AMQ', 'TPM', 'KSF', 'CUX', 'BQM', 'JHW', 'BLH', 'CTH', 'HSRA', 'MUY', 'SDT', 'KUTI', 'BLK', 'ARAG', 'MUO', 'KRLS', 'NDV', 'BRMI', 'BIH', 'MRN', 'BMNI', 'MAN', 'NNPR', 'BOR', 'TRS', 'GSO', 'GG', 'GMAN', 'DKWA', 'DDS', 'NRSP', 'KODI', 'SPB', 'BNOD', 'KPO', 'PSJ', 'AWG', 'TGQ', 'KHNP', 'PLY', 'SZP', 'JLN', 'SHLK', 'NWB', 'MYY', 'HPG', 'QLD', 'KUCH', 'UDN', 'HTN', 'BSPH', 'BZG', 'TMPM', 'DJG', 'GAGA', 'VZM', 'KPK', 'SMKT', 'SMBX', 'LBO', 'MSDL', 'MAI', 'DEOR', 'GOD', 'RBR', 'BID', 'KPG', 'HRSN', 'ANVR', 'MWT', 'LLKN', 'AKOR', 'GNPR', 'KRY', 'UB', 'PRWD', 'CLC', 'MMD', 'DWLE', 'SIP', 'DBA', 'SLO', 'TLG', 'RKSH', 'PBR', 'DRHI', 'NSRH', 'JPP', 'SILO', 'KTKS', 'KLV', 'BBDE', 'DHN', 'YJUD', 'PTHL', 'MBD', 'DJR', 'GTY', 'NID', 'MGPI', 'NPRD', 'PAE', 'GNG', 'MBM', 'MNO', 'CRX', 'BTJ', 'YGL', 'BBTR', 'KJG', 'DMU', 'SRX', 'KMH', 'JID', 'MLM', 'SJRR', 'KHED', 'BRMD', 'GIN', 'SP', 'BS', 'MAV', 'UWNR', 'BGKA', 'ADRA', 'TLH', 'MRIJ', 'NXN', 'KGW', 'PLMD', 'HDW', 'BZN', 'RKX', 'HBU', 'SFH', 'RAA', 'RJGR', 'BRQ', 'MIO', 'SLWR', 'TMP', 'ENB', 'UHL', 'MGS', 'VLD', 'UJA', 'MAUL', 'GKP', 'NMK', 'CHBR', 'NRGR', 'AED', 'KY', 'RMU', 'GNN', 'AILM', 'NUR', 'KLKA', 'PATL', 'CGS', 'SRE', 'PDU', 'UTR', 'SNO', 'PBL', 'KAMP', 'BRDB', 'BTIC', 'THS', 'GPX', 'MGKP', 'LHBK', 'SHMI', 'AY', 'SRNT', 'CKD', 'ZP', 'MDSE', 'GADJ', 'RAIR', 'SDB', 'USRA', 'SHDR', 'RDP', 'MLDT', 'GHR', 'JLT', 'FKG', 'DGFJ', 'KRMA', 'GKB', 'PYV', 'HNA', 'MRC', 'EGU', 'JAMA', 'DAVC', 'HGY', 'HEI', 'VMP', 'TUP', 'HT', 'GHE', 'DIBL', 'SUW', 'BBO', 'MES', 'CII', 'NLV', 'TPC', 'KON', 'NRPR', 'MFA', 'CLA', 'VRA', 'CTHR', 'RBHR', 'KRUR', 'MVO', 'MRJ', 'GNS', 'BJM', 'KUGT', 'KWI', 'NOLB', 'ROL', 'JMIR', 'ICL', 'MJM', 'SWNR', 'HHT', 'DRGU', 'KEMR', 'BKTW', 'KYX', 'URGA', 'KYM', 'BFM', 'RAJP', 'MTIP', 'ACG', 'NRK', 'SPZ', 'DDGJ', 'DLP', 'BSDL', 'ITKY', 'OSA', 'GADH', 'STH', 'VPDA', 'CLDB', 'KJ', 'YG', 'DLDE', 'GUD', 'GBQ', 'MNKD', 'GGT', 'DUB', 'DOY', 'MAP', 'PRG', 'BDVT', 'LTT', 'SATR', 'DWX', 'VZR', 'SEGM', 'MBQ', 'BPJ', 'IDT', 'PWBN', 'KNHN', 'KZW', 'SVKD', 'LO', 'FZR', 'QDN', 'BAK', 'CMC', 'MDJN', 'ATKS', 'SNAR', 'RDY', 'GJMB', 'VHGN', 'PUX', 'UBN', 'SBK', 'PNU', 'BLSN', 'SEH', 'JNZ', 'DCX', 'JVA', 'MSRP', 'OSN', 'SRPN', 'KTKL', 'SJSM', 'AFR', 'BZ', 'KZX', 'TALA', 'KKGT', 'BHN', 'DHR', 'SWRT', 'DNJ', 'PNW', 'ANCR', 'MSDG', 'ALLP', 'HNH', 'BXB', 'CDRL', 'TPQ', 'BVO', 'BHA', 'SPLE', 'KRNT', 'TMZ', 'BAW', 'NBA', 'KGRA', 'GHSR', 'MGC', 'PPLC', 'BPC', 'RFJ', 'DSME', 'CTMP', 'RTGN', 'RRL', 'HRG', 'TWB', 'VG', 'CLDR', 'AGB', 'PLH', 'TALL', 'NDRT', 'CHL', 'ASAR', 'PRKH', 'ROHA', 'GPI', 'BHKH', 'SKN', 'TLL', 'BLTR', 'BJA', 'BNO', 'SM', 'MWF', 'CBM', 'LSX', 'VKG', 'UBC', 'SMRR', 'BMBE', 'YS', 'PRH', 'MDLL', 'JPZ', 'ADB', 'SJNP', 'SINI', 'JES', 'RNJ', 'KEJ', 'PCQ', 'SMGR', 'RSG', 'DBN', 'DFR', 'ME', 'CCD', 'VONB', 'PDGM', 'BHBV', 'UDPR', 'SNYN', 'NH', 'LOA', 'BNQL', 'JBN', 'OCR', 'KJM', 'BLO', 'IP', 'BETI', 'SSZ', 'NAD', 'PRDG', 'PJP', 'ADX', 'VPO', 'KRJR', 'PSL', 'KPLR', 'RTG', 'AJK', 'LDK', 'NVU', 'KHKT', 'HFZ', 'KNRG', 'IGP', 'KHBJ', 'KRR', 'BWF', 'ASCE', 'ASKN', 'SBE', 'TRWT', 'MURI', 'ILO', 'DARA', 'BTRA', 'NGM', 'KRHT', 'HHG', 'PRTN', 'SVM', 'SFDE', 'DVJ', 'BILD', 'SAT', 'TLD', 'PKA', 'QMRS', 'RAPU', 'CKYD', 'MKX', 'UKV', 'NBR', 'FTS', 'KDQ', 'FUT', 'GSB', 'SSP', 'PCU', 'BIF', 'SKG', 'VAL', 'KTW', 'BD', 'SMBH', 'MDW', 'SXC', 'MZY', 'ACH', 'BIK', 'LKKD', 'LUNI', 'MBNR', 'GED', 'NOR', 'CGN', 'KXE', 'GJ', 'NNO', 'SRDR', 'MITA', 'STKT', 'DXK', 'ARK', 'BLRG', 'BNRD', 'MRG', 'MHH', 'GHRI', 'NHN', 'BUJ', 'RRW', 'MKRH', 'DTO', 'BJF', 'RG', 'WRR', 'BTT', 'BFE', 'KUC', 'MLD', 'CRY', 'DZL', 'VNGL', 'KBRV', 'FZD', 'DSK', 'PTAE', 'SAU', 'KMZ', 'KWJ', 'KRTN', 'ARN', 'RYC', 'MHV', 'SOAE', 'RNL', 'SSPD', 'KRAR', 'SLW', 'CBG', 'PIA', 'BTSR', 'PCX', 'DAVJ', 'IQG', 'NNU', 'PPI', 'BUBR', 'GDD', 'ODM', 'TBT', 'KRLR', 'MBY', 'HTZU', 'LXA', 'MZA', 'PRGR', 'SNLR', 'SMET', 'MNTT', 'BRD', 'KIG', 'KRMD', 'KM ...

# %%
def get_ddist(g):
    l = len(g)
    d = dict()
    for i in range(0,l):
        if g[i] in d.keys():
            d[g[i]] = d[g[i]] + 1
        else:
            d[g[i]] = 1
    return d

# %%
i = 1
for h in nx.connected_components(G):
    k = nx.subgraph(G,h)
    print("No of nodes in " + str(i) + "th subgraph are " + str(len(k.nodes)))
    i = i +1
    degree1 = dict(k.degree)
    count1 = 0
    count2 = 0
    ap = list(nx.articulation_points(k))
    for d in degree1.keys():
        if degree1[d] == 1:
            count1 = count1 + 1
        if degree1[d] == 2:
            count2 = count2 + 1
    print("For " + str(i) + "th subgraph, nodes with degree 1 = " + str(count1) + " nodes with degree 2 = " + str(count2))
    print("No of AP = " + str(len(ap)))
    #print("Articulation points are: " + str(ap))
# Out:
# No of nodes in 1th subgraph are 8060
# For 2th subgraph, nodes with degree 1 = 122 nodes with degree 2 = 4412
# No of AP = 804
# No of nodes in 2th subgraph are 29
# For 3th subgraph, nodes with degree 1 = 2 nodes with degree 2 = 18
# No of AP = 17
# No of nodes in 3th subgraph are 12
# For 4th subgraph, nodes with degree 1 = 3 nodes with degree 2 = 8
# No of AP = 9
# No of nodes in 4th subgraph are 10
# For 5th subgraph, nodes with degree 1 = 3 nodes with degree 2 = 6
# No of AP = 7
# No of nodes in 5th subgraph are 17
# For 6th subgraph, nodes with degree 1 = 2 nodes with degree 2 = 15
# No of AP = 15
# No of nodes in 6th subgraph are 17
# For 7th subgraph, nodes with degree 1 = 1 nodes with degree 2 = 10
# No of AP = 7
# No of nodes in 7th subgraph are 3
# For 8th subgraph, nodes with degree 1 = 2 nodes with degree 2 = 1
# No of AP = 1

# %%
def get_ddist(g):
    l = len(g)
    d = dict()
    for i in range(0,l):
        if g[i] in d.keys():
            d[g[i]] = d[g[i]] + 1
        else:
            d[g[i]] = 1
    return d

# %%
dict1 = G.
get_ddist()

# %%
h = list(nx.connected_components(G))

# %%
print(h[0])
# Out:
# {'BGZ', 'BKPR', 'NKW', 'ETR', 'BVR', 'KGN', 'SSGR', 'BTR', 'CDB', 'UBR', 'DGG', 'GTJT', 'NIIJ', 'FRDH', 'SSG', 'DGPP', 'AMQ', 'TPM', 'KSF', 'CUX', 'BQM', 'JHW', 'BLH', 'CTH', 'HSRA', 'MUY', 'SDT', 'KUTI', 'BLK', 'ARAG', 'MUO', 'KRLS', 'NDV', 'BRMI', 'BIH', 'MRN', 'BMNI', 'MAN', 'NNPR', 'BOR', 'TRS', 'GSO', 'GG', 'GMAN', 'DKWA', 'DDS', 'NRSP', 'KODI', 'SPB', 'BNOD', 'KPO', 'PSJ', 'AWG', 'TGQ', 'KHNP', 'PLY', 'SZP', 'JLN', 'SHLK', 'NWB', 'MYY', 'HPG', 'QLD', 'KUCH', 'UDN', 'HTN', 'BSPH', 'BZG', 'TMPM', 'DJG', 'GAGA', 'VZM', 'KPK', 'SMKT', 'SMBX', 'LBO', 'MSDL', 'MAI', 'DEOR', 'GOD', 'RBR', 'BID', 'KPG', 'HRSN', 'ANVR', 'MWT', 'LLKN', 'AKOR', 'GNPR', 'KRY', 'UB', 'PRWD', 'CLC', 'MMD', 'DWLE', 'SIP', 'DBA', 'SLO', 'TLG', 'RKSH', 'PBR', 'DRHI', 'NSRH', 'JPP', 'SILO', 'KTKS', 'KLV', 'BBDE', 'DHN', 'YJUD', 'PTHL', 'MBD', 'DJR', 'GTY', 'NID', 'MGPI', 'NPRD', 'PAE', 'GNG', 'MBM', 'MNO', 'CRX', 'BTJ', 'YGL', 'BBTR', 'KJG', 'DMU', 'SRX', 'KMH', 'JID', 'MLM', 'SJRR', 'KHED', 'BRMD', 'GIN', 'SP', 'BS', 'MAV', 'UWNR', 'BGKA', 'ADRA', 'TLH', 'MRIJ', 'NXN', 'KGW', 'PLMD', 'HDW', 'BZN', 'RKX', 'HBU', 'SFH', 'RAA', 'RJGR', 'BRQ', 'MIO', 'SLWR', 'TMP', 'ENB', 'UHL', 'MGS', 'VLD', 'UJA', 'MAUL', 'GKP', 'NMK', 'CHBR', 'NRGR', 'AED', 'KY', 'RMU', 'GNN', 'AILM', 'NUR', 'KLKA', 'PATL', 'CGS', 'SRE', 'PDU', 'UTR', 'SNO', 'PBL', 'KAMP', 'BRDB', 'BTIC', 'THS', 'GPX', 'MGKP', 'LHBK', 'SHMI', 'AY', 'SRNT', 'CKD', 'ZP', 'MDSE', 'GADJ', 'RAIR', 'SDB', 'USRA', 'SHDR', 'RDP', 'MLDT', 'GHR', 'JLT', 'FKG', 'DGFJ', 'KRMA', 'GKB', 'PYV', 'HNA', 'MRC', 'EGU', 'JAMA', 'DAVC', 'HGY', 'HEI', 'VMP', 'TUP', 'HT', 'GHE', 'DIBL', 'SUW', 'BBO', 'MES', 'CII', 'NLV', 'TPC', 'KON', 'NRPR', 'MFA', 'CLA', 'VRA', 'CTHR', 'RBHR', 'KRUR', 'MVO', 'MRJ', 'GNS', 'BJM', 'KUGT', 'KWI', 'NOLB', 'ROL', 'JMIR', 'ICL', 'MJM', 'SWNR', 'HHT', 'DRGU', 'KEMR', 'BKTW', 'KYX', 'URGA', 'KYM', 'BFM', 'RAJP', 'MTIP', 'ACG', 'NRK', 'SPZ', 'DDGJ', 'DLP', 'BSDL', 'ITKY', 'OSA', 'GADH', 'STH', 'VPDA', 'CLDB', 'KJ', 'YG', 'DLDE', 'GUD', 'GBQ', 'MNKD', 'GGT', 'DUB', 'DOY', 'MAP', 'PRG', 'BDVT', 'LTT', 'SATR', 'DWX', 'VZR', 'SEGM', 'MBQ', 'BPJ', 'IDT', 'PWBN', 'KNHN', 'KZW', 'SVKD', 'LO', 'FZR', 'QDN', 'BAK', 'CMC', 'MDJN', 'ATKS', 'SNAR', 'RDY', 'GJMB', 'VHGN', 'PUX', 'UBN', 'SBK', 'PNU', 'BLSN', 'SEH', 'JNZ', 'DCX', 'JVA', 'MSRP', 'OSN', 'SRPN', 'KTKL', 'SJSM', 'AFR', 'BZ', 'KZX', 'TALA', 'KKGT', 'BHN', 'DHR', 'SWRT', 'DNJ', 'PNW', 'ANCR', 'MSDG', 'ALLP', 'HNH', 'BXB', 'CDRL', 'TPQ', 'BVO', 'BHA', 'SPLE', 'KRNT', 'TMZ', 'BAW', 'NBA', 'KGRA', 'GHSR', 'MGC', 'PPLC', 'BPC', 'RFJ', 'DSME', 'CTMP', 'RTGN', 'RRL', 'HRG', 'TWB', 'VG', 'CLDR', 'AGB', 'PLH', 'TALL', 'NDRT', 'CHL', 'ASAR', 'PRKH', 'ROHA', 'GPI', 'BHKH', 'SKN', 'TLL', 'BLTR', 'BJA', 'BNO', 'SM', 'MWF', 'CBM', 'LSX', 'VKG', 'UBC', 'SMRR', 'BMBE', 'YS', 'PRH', 'MDLL', 'JPZ', 'ADB', 'SJNP', 'SINI', 'JES', 'RNJ', 'KEJ', 'PCQ', 'SMGR', 'RSG', 'DBN', 'DFR', 'ME', 'CCD', 'VONB', 'PDGM', 'BHBV', 'UDPR', 'SNYN', 'NH', 'LOA', 'BNQL', 'JBN', 'OCR', 'KJM', 'BLO', 'IP', 'BETI', 'SSZ', 'NAD', 'PRDG', 'PJP', 'ADX', 'VPO', 'KRJR', 'PSL', 'KPLR', 'RTG', 'AJK', 'LDK', 'NVU', 'KHKT', 'HFZ', 'KNRG', 'IGP', 'KHBJ', 'KRR', 'BWF', 'ASCE', 'ASKN', 'SBE', 'TRWT', 'MURI', 'ILO', 'DARA', 'BTRA', 'NGM', 'KRHT', 'HHG', 'PRTN', 'SVM', 'SFDE', 'DVJ', 'BILD', 'SAT', 'TLD', 'PKA', 'QMRS', 'RAPU', 'CKYD', 'MKX', 'UKV', 'NBR', 'FTS', 'KDQ', 'FUT', 'GSB', 'SSP', 'PCU', 'BIF', 'SKG', 'VAL', 'KTW', 'BD', 'SMBH', 'MDW', 'SXC', 'MZY', 'ACH', 'BIK', 'LKKD', 'LUNI', 'MBNR', 'GED', 'NOR', 'CGN', 'KXE', 'GJ', 'NNO', 'SRDR', 'MITA', 'STKT', 'DXK', 'ARK', 'BLRG', 'BNRD', 'MRG', 'MHH', 'GHRI', 'NHN', 'BUJ', 'RRW', 'MKRH', 'DTO', 'BJF', 'RG', 'WRR', 'BTT', 'BFE', 'KUC', 'MLD', 'CRY', 'DZL', 'VNGL', 'KBRV', 'FZD', 'DSK', 'PTAE', 'SAU', 'KMZ', 'KWJ', 'KRTN', 'ARN', 'RYC', 'MHV', 'SOAE', 'RNL', 'SSPD', 'KRAR', 'SLW', 'CBG', 'PIA', 'BTSR', 'PCX', 'DAVJ', 'IQG', 'NNU', 'PPI', 'BUBR', 'GDD', 'ODM', 'TBT', 'KRLR', 'MBY', 'HTZU', 'LXA', 'MZA', 'PRGR', 'SNLR', 'SMET', 'MNTT', 'BRD', 'KIG', 'KRMD', 'KMM ...

# %%
G1 = nx.subgraph(G,h[0])

# %%
len(G1.nodes)
# Out:
# 8060

# %%
dict1 = dict(G1.degree())
dd = get_ddist(list(dict1.values()))

# %%
dd
# Out:
# {9: 106,
#  6: 323,
#  18: 15,
#  8: 148,
#  5: 486,
#  3: 1039,
#  20: 10,
#  4: 866,
#  7: 183,
#  23: 6,
#  10: 80,
#  15: 23,
#  19: 6,
#  12: 42,
#  16: 21,
#  28: 5,
#  39: 2,
#  32: 2,
#  11: 51,
#  34: 1,
#  14: 39,
#  24: 2,
#  13: 33,
#  44: 1,
#  17: 13,
#  25: 3,
#  22: 4,
#  21: 9,
#  29: 2,
#  30: 2,
#  2: 4412,
#  33: 1,
#  1: 122,
#  26: 1,
#  27: 1}

# %%
type(dd)
# Out:
# dict

# %%
dds = dict(sorted(dd.items()))
plt.plot(dds.keys(),dds.values())
plt.title('Degree distribution')
plt.xlabel('Degree')
plt.ylabel('No of nodes')
# Out:
# Text(0, 0.5, 'No of nodes')

# %%
dds
# Out:
# {1: 122,
#  2: 4412,
#  3: 1039,
#  4: 866,
#  5: 486,
#  6: 323,
#  7: 183,
#  8: 148,
#  9: 106,
#  10: 80,
#  11: 51,
#  12: 42,
#  13: 33,
#  14: 39,
#  15: 23,
#  16: 21,
#  17: 13,
#  18: 15,
#  19: 6,
#  20: 10,
#  21: 9,
#  22: 4,
#  23: 6,
#  24: 2,
#  25: 3,
#  26: 1,
#  27: 1,
#  28: 5,
#  29: 2,
#  30: 2,
#  32: 2,
#  33: 1,
#  34: 1,
#  39: 2,
#  44: 1}

# %%
apl = nx.average_shortest_path_length(G1)

# %%
print(apl)
# Out:
# 11.028701293223026

# %%
acc = nx.clustering(G1)

# %%
print(acc)
# Out:
# {'SWV': 0.5277777777777778, 'THVM': 0.6111111111111112, 'KRMI': 0.6666666666666666, 'MAO': 0.16339869281045752, 'KUDL': 0.6428571428571429, 'SNDD': 0.8, 'KKW': 0.5, 'VBW': 0.3333333333333333, 'RAJP': 0.4, 'RN': 0.17894736842105263, 'SGR': 0.16666666666666666, 'CHI': 0.2857142857142857, 'KHED': 0.42857142857142855, 'MNI': 0.42857142857142855, 'ROHA': 0.2857142857142857, 'PNVL': 0.1422924901185771, 'KJT': 0.2, 'LNL': 0.24761904761904763, 'PUNE': 0.13725490196078433, 'STR': 0.2857142857142857, 'MRJ': 0.08771929824561403, 'KOP': 0.3333333333333333, 'DSJ': 0.15151515151515152, 'GADJ': 0.47619047619047616, 'JP': 0.17647058823529413, 'DPA': 0.5, 'SWM': 0.12418300653594772, 'COR': 0.10833333333333334, 'UDZ': 0, 'JSM': 0.1, 'MDB': 0.2, 'FL': 0.15, 'BTE': 0.13071895424836602, 'IDH': 0.19047619047619047, 'AGC': 0.1503267973856209, 'AWB': 0.13333333333333333, 'MMR': 0.12105263157894737, 'BSL': 0.10846560846560846, 'KNW': 0.17142857142857143, 'JHS': 0.09523809523809523, 'CNB': 0.0620782726045884, 'LKO': 0.07459677419354839, 'BBK': 0.16666666666666666, 'AY': 0.19696969696969696, 'SHG': 0.21818181818181817, 'JNU': 0.14166666666666666, 'BSB': 0.09982174688057041, 'FGR': 0.23809523809523808, 'KSJ': 0.08791208791208792, 'BE': 0.10869565217391304, 'SVDK': 0.3333333333333333, 'SSA': 0.14285714285714285, 'HSR': 0.0641025641025641, 'BNW': 0.10909090909090909, 'ROK': 0.0784313725490196, 'MGS': 0.06620209059233449, 'RJPB': 0.6666666666666666, 'SNP': 0.23076923076923078, 'PNP': 0.1736842105263158, 'KUN': 0.3333333333333333, 'KKDE': 0.2, 'UMB': 0.1368421052631579, 'PNBE': 0.13970588235294118, 'BTI': 0.05, 'PTA': 0.17857142857142858, 'URK': 0.3333333333333333, 'PJP': 0.16666666666666666, 'ASR': 0.07272727272727272, 'CSMT': 0.18681318681318682, 'DR': 0.3111111111111111, 'TNA': 0.18382352941176472, 'KYN': 0.15019762845849802, 'IGP': 0.26666666666666666, 'NK': 0.26666666666666666, 'JL': 0.19696969696969696, 'MKU': 0.2777777777777778, 'SEG': 0.38095238095238093, 'AK': 0.14285714285714285, 'MZR': 0.16666666666666666, 'BD': 0.15555555555555556, 'DMN': 0.2857142857142857, 'PLO': 0.3333333333333333, 'WR': 0.20952380952380953, 'NGP': 0.1164021164021164, 'LTT': 0.38095238095238093, 'AJNI': 0.6, 'CSN': 0.17777777777777778, 'KAWR': 0.26666666666666666, 'KT': 0.42857142857142855, 'KUDA': 0.4, 'UD': 0.19230769230769232, 'MULK': 0.5, 'MAJN': 0.15384615384615385, 'MTJ': 0.09881422924901186, 'GWL': 0.125, 'BPL': 0.1871345029239766, 'ET': 0.12554112554112554, 'DD': 0.13333333333333333, 'KK': 0.47619047619047616, 'ANG': 0.2222222222222222, 'KPG': 0.32142857142857145, 'HD': 0.2777777777777778, 'PPI': 0.2777777777777778, 'NU': 0.25, 'MML': 0.3333333333333333, 'JBP': 0.18681318681318682, 'BDTS': 0.6666666666666666, 'BVI': 0.34285714285714286, 'VAPI': 0.2967032967032967, 'ST': 0.17647058823529413, 'BRC': 0.10333333333333333, 'RTM': 0.1, 'UJN': 0.14102564102564102, 'BIH': 0.4, 'HBD': 0.38095238095238093, 'KMZ': 0.16483516483516483, 'DMO': 0.3333333333333333, 'SGO': 0.17582417582417584, 'MAKR': 0.42857142857142855, 'LAR': 0.15384615384615385, 'NDLS': 0.13306451612903225, 'LDH': 0.0812807881773399, 'JUC': 0.08571428571428572, 'BEAS': 0.16666666666666666, 'ATT': 0, 'SHR': 0.32142857142857145, 'KTE': 0.11695906432748537, 'UMR': 0.2777777777777778, 'SDL': 0.2222222222222222, 'APR': 0.1388888888888889, 'PND': 0.19444444444444445, 'BSP': 0.125, 'CPH': 0.18181818181818182, 'RIG': 0.2222222222222222, 'JSG': 0.14285714285714285, 'ROU': 0.10989010989010989, 'CKP': 0.16666666666666666, 'TATA': 0.11462450592885376, 'KGP': 0.08505747126436781, 'SRC': 0.21978021978021978, 'REWA': 0, 'STA': 0.12631578947368421, 'MYR': 0.3333333333333333, 'JKE': 0.4, 'BINA': 0.16993464052287582, 'BHS': 0.26666666666666666, 'TVC': 0.2545454545454545, 'QLN': 0.13071895424836602, 'KYJ': 0.2222222222222222, 'MVLK': 0.6666666666666666, 'CNGR': 0.4666666666666667, 'TRVL': 0.5, 'KTYM': 0.19230769230769232, 'ERN': 0.42857142857142855, 'AWY': 0.3333333333333333, 'TCR': 0.21978021978021978, 'PGT': 0.13333333333333333, ' ...

# %%
acc_dict = dict(acc)
#print(acc_dict)
#sorted(acc_dict.values())
#sorted(acc_dict.values())
acc_dds = get_ddist(list(acc_dict.values()))
dds = dict(sorted(acc_dds.items()))
plt.plot(dds.keys(),dds.values())
plt.title('Clustering Coefficient')
plt.xlabel('Clustering Coefficient')
plt.ylabel('No of nodes')
print("Maximum cc = " + str(max(acc_dict.values())))
print("Minimum cc = " + str(min(acc_dict.values())))
# Out:
# Maximum cc = 1.0
# Minimum cc = 0

# %%
keys = list(acc_dict.keys())
count0 = 0
count1 = 1
for i in range(len(keys)):
    if acc_dict[keys[i]] == 0:
        count0 = count0 + 1
    if acc_dict[keys[i]] == 1:
        count1 = count1 + 1
print("Count0 = " + str(count0))
print("Count1 = " + str(count1))
print("Average cc = " + str((sum(acc_dict.values())/len(acc_dict.values()))))
# Out:
# Count0 = 3122
# Count1 = 1644
# Average cc = 0.35394250685297945

# %%
series = pd.Series(acc_dict)
series.sort_values(axis=0, ascending=False, inplace=True, kind='quicksort', na_position='last', ignore_index=False, key=None)
min((series.to_dict().values()))
# Out:
# 0.0

# %%
bridge_links = list(nx.bridges(G1))
print(len(bridge_links))
# Out:
# 657

# %%
ap = list(nx.articulation_points(G1))
print(len(ap))
# Out:
# 804

# %%
count = 0
c7 = 0
nap = np.empty((len(ap),3),dtype='S5')
for a in ap:
    G2 = nx.Graph(G1)
    G2.remove_node(a)
    h1 = list(nx.connected_components(G2))
    G21 = nx.subgraph(G2,h1[0])
    G22 = nx.subgraph(G2,h1[1])
    n1 = len(list(G21.nodes))
    n2 = len(list(G22.nodes))
    nap[count,0] = a
    nap[count,1] = str(n1)
    nap[count,2] = str(n2)
    count = count + 1
    
    if abs(n1 - n2) < 7000:
        print("Articulation point: " + str(a))
        print("The graph is split into " + str(n1) + " " + str(n2)) 
        c7 = c7 + 1
    if abs(n1 - n2) < 7500 and count > 100 and c7 < 10:
        print("Articulation point: " + str(a))
        print("The graph is split into " + str(n1) + " " + str(n2))
    if abs(n1 - n2) < 8000 and count > 200 and c7 < 10:
        print("Articulation point: " + str(a))
        print("The graph is split into " + str(n1) + " " + str(n2))
# Out:
# Articulation point: MXN
# The graph is split into 8006 53
# Articulation point: DMV
# The graph is split into 7980 79
# Articulation point: DPU
# The graph is split into 7975 84
# Articulation point: LMG
# The graph is split into 7971 88
# Articulation point: GHY
# The graph is split into 7837 222
# Articulation point: RPAN
# The graph is split into 8013 43
# Articulation point: RNY
# The graph is split into 7999 60
# Articulation point: MALA
# The graph is split into 8029 30
# Articulation point: PBE
# The graph is split into 8010 32
# Articulation point: SSC
# The graph is split into 8008 51
# Articulation point: BJV
# The graph is split into 8007 52
# Articulation point: STH
# The graph is split into 8006 53
# Articulation point: BPR
# The graph is split into 8004 55
# Articulation point: RHA
# The graph is split into 8026 33
# Articulation point: BLN
# The graph is split into 8009 50
# Articulation point: NUPR
# The graph is split into 8029 30
# Articulation point: DLSR
# The graph is split into 8027 32
# Articulation point: PTK
# The graph is split into 8026 33
# Articulation point: BTD
# The graph is split into 8020 39

# %%
nap
# Out:
# array([[b'PNQ', b'8058', b'1'],
#        [b'LOV', b'8058', b'1'],
#        [b'KXT', b'8057', b'2'],
#        ...,
#        [b'CQA', b'8052', b'7'],
#        [b'VPZ', b'8050', b'9'],
#        [b'SRR', b'8048', b'11']], dtype='|S5')

# %%
for i in range(len(nap)):
    if int(nap[i,2]) == 222:
           print(nap[i,0])
for i in range(len(nap)):
    if int(nap[i,2]) == 105:
           print(nap[i,0])
for i in range(len(nap)):
    if int(nap[i,2]) == 88:
           print(nap[i,0])
for i in range(len(nap)):
    if int(nap[i,2]) == 84:
           print(nap[i,0])
for i in range(len(nap)):
    if int(nap[i,2]) == 79:
           print(nap[i,0])
# Out:
# b'GHY'
# b'RJT'
# b'LMG'
# b'DPU'
# b'DMV'

# %%
lnap = nap[:,2]
knap = np.empty(len(lnap))
ic = 0
for i in lnap:
    knap[ic] = int(i)
    ic = ic + 1
apdict = dict()
ni = 0
for ni in range(len(nap)):
    k = int(nap[ni,2])
    if k in apdict.keys():
        apdict[k] = apdict[k] + 1
    else:
        apdict[k] = 1
dap = dict(sorted(apdict.items()))
plt.plot(dap.keys(),dap.values())
plt.title('Articulation points')
plt.xlabel('No of nodes in smaller graph')
plt.ylabel('No of Articulation points')
# Out:
# Text(0, 0.5, 'No of Articulation points')

# %%
dap
# Out:
# {1: 118,
#  2: 98,
#  3: 76,
#  4: 66,
#  5: 61,
#  6: 54,
#  7: 48,
#  8: 34,
#  9: 30,
#  10: 32,
#  11: 25,
#  12: 23,
#  13: 17,
#  14: 14,
#  15: 16,
#  16: 12,
#  17: 8,
#  18: 7,
#  19: 9,
#  20: 4,
#  21: 4,
#  22: 4,
#  23: 8,
#  24: 3,
#  25: 3,
#  26: 3,
#  27: 1,
#  28: 2,
#  29: 1,
#  30: 2,
#  32: 2,
#  33: 2,
#  37: 1,
#  38: 1,
#  39: 2,
#  43: 1,
#  50: 1,
#  51: 1,
#  52: 1,
#  53: 2,
#  55: 1,
#  60: 1,
#  79: 1,
#  84: 1,
#  88: 1,
#  105: 1,
#  222: 1}
